# %%
import pandas as pd

# %%
df=pd.read_csv('../coronavirusChallenge/data/allData.csv')

# %%
df['Fecha Actualizacion']=df['Fecha Actualizacion'].str.replace('/', '-')

# %%
fecha='2020-04-01'

# %%
df[df['Fecha Actualizacion']==fecha]
# Out:
#         No            Estado Sexo  Edad Fecha inicio síntomas      Status  \
# 8046     1  Ciudad De México    M  35.0            22/02/2020  Confirmado
# 8047     2           Sinaloa    M  41.0            22/02/2020  Confirmado
# 8048     3  Ciudad De México    M  59.0            23/02/2020  Confirmado
# 8049     4          Coahuila    F  20.0            27/02/2020  Confirmado
# 8050     5           Chiapas    F  18.0            25/02/2020  Confirmado
# ...    ...               ...  ...   ...                   ...         ...
# 9419  1374  Ciudad De México    F  54.0            25/03/2020  Confirmado
# 9420  1375           Nayarit    F  79.0            24/03/2020  Confirmado
# 9421  1376        Nuevo León    F  46.0            28/03/2020  Confirmado
# 9422  1377            Puebla    M  49.0            23/03/2020  Confirmado
# 9423  1378   San Luis Potosí    F  41.0            27/03/2020  Confirmado
#
#          Procedencia Fecha llegada Mexico Recuperado Fecha Actualizacion
# ...

# %%
import urllib.request, json 
with urllib.request.urlopen("http://127.0.0.1:5000/date/2020-04-05") as url:
    data = json.loads(url.read().decode())
    print(data)
# Out:
# {"No":{"14512":1,"14513":2,"14514":3,"14515":4,"14516":5,"14517":6,"14518":7,"14519":8,"14520":9,"14521":10,"14522":11,"14523":12,"14524":13,"14525":14,"14526":15,"14527":16,"14528":17,"14529":18,"14530":19,"14531":20,"14532":21,"14533":22,"14534":23,"14535":24,"14536":25,"14537":26,"14538":27,"14539":28,"14540":29,"14541":30,"14542":31,"14543":32,"14544":33,"14545":34,"14546":35,"14547":36,"14548":37,"14549":38,"14550":39,"14551":40,"14552":41,"14553":42,"14554":43,"14555":44,"14556":45,"14557":46,"14558":47,"14559":48,"14560":49,"14561":50,"14562":51,"14563":52,"14564":53,"14565":54,"14566":55,"14567":56,"14568":57,"14569":58,"14570":59,"14571":60,"14572":61,"14573":62,"14574":63,"14575":64,"14576":65,"14577":66,"14578":67,"14579":68,"14580":69,"14581":70,"14582":71,"14583":72,"14584":73,"14585":74,"14586":75,"14587":76,"14588":77,"14589":78,"14590":79,"14591":80,"14592":81,"14593":82,"14594":83,"14595":84,"14596":85,"14597":86,"14598":87,"14599":88,"14600":89,"14601":90,"14602":91
# ...

# %%
pd.read_json(data)
# Out:
#          No            Estado Sexo  Edad Fecha inicio síntomas      Status  \
# 14512     1  Ciudad De México    M    35            22/02/2020  Confirmado
# 14513     2           Sinaloa    M    41            22/02/2020  Confirmado
# 14514     3  Ciudad De México    M    59            23/02/2020  Confirmado
# 14515     4          Coahuila    F    20            27/02/2020  Confirmado
# 14516     5           Chiapas    F    18            25/02/2020  Confirmado
# ...     ...               ...  ...   ...                   ...         ...
# 16650  2139  Ciudad De México    F    68            20/03/2020  Confirmado
# 16651  2140  Ciudad De México    M    34            20/03/2020  Confirmado
# 16652  2141  Ciudad De México    F    65            21/03/2020  Confirmado
# 16653  2142  Ciudad De México    M    60            22/03/2020  Confirmado
# 16654  2143  Ciudad De México    M    49            19/03/2020  Confirmado
#
# ...

# %%
from flask import Flask, request
from flask_restful import Resource, Api

app = Flask(__name__)
api = Api(app)

todos = {}

class TodoSimple(Resource):
    def get(self, fecha):
        return df[df['Fecha Actualizacion']==fecha]

api.add_resource(TodoSimple, '/date/<string:fecha>')

if __name__ == '__main__':
    app.run(debug=True)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Restarting with stat
